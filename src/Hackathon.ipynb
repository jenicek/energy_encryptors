# %%
import pandas as pd

# %%
dataset = pd.read_csv('smart_meters_london_2013.csv')

# %%
dataset = dataset.T

# %%
dataset
# Out:
#                           0                    1                    2     \
# timestamp  2013-01-01 00:00:00  2013-01-01 01:00:00  2013-01-01 02:00:00
# 0                         0.46                0.426                0.411
# 1                        3.888                2.603                2.159
# 2                          0.0                0.158                  0.0
# 3                        0.207                0.106                0.069
# ...                        ...                  ...                  ...
# 4120                     0.246                0.221                0.207
# 4121                     0.141                0.131                0.131
# 4122                     0.547                0.474                0.252
# 4123                     0.215                0.227                 0.22
# 4124                     0.119                0.103                0.285
#
#                           3                    4                    5     \
# timestamp  2013-01-01 03:00:00  2013-01-01 04:00:00  2013-01-01 05:00:00
# 0                        0.395                0.221                0.206
# 1                         2.04                1.495                1.044
# 2                         0.17                  0.0                  0.0
# 3                        0.065                0.058                0.068
# ...                        ...                  ...                  ...
# 4120                      0.22                0.238                0.167
# 4121                     0.104                0.119                0.123
# 4122                     0.091                0.086                0.101
# 4123                     0.202                0.208                0.181
# 4124                     0.097                0.103                0.083
#
#                           6                    7                    8     \
# timestamp  2013-01-01 06:00:00  2013-01-01 07:00:00  2013-01-01 08:00:00
# 0                        0.206                0.217                0.216
# 1                        0.807                0.227                 0.15
# 2                        0.176                  0.0                0.176
# 3                        0.069                0.086                0.447
# ...                        ...                  ...                  ...
# 4120                     0.131                0.132                0.183
# 4121                     0.091                0.138                0.229
# 4122                     0.097                0.096                0.103
# 4123                     0.264                0.251                0.217
# 4124                     0.097                0.089                0.106
#
#                           9     ...                 8750                 8751  \
# timestamp  2013-01-01 09:00:00  ...  2013-12-31 14:00:00  2013-12-31 15:00:00
# 0                        0.216  ...                 0.62                1.034
# 1                        0.231  ...                0.252                0.127
# 2                          0.0  ...                 0.24                  0.0
# 3                        0.092  ...                0.253                 0.12
# ...                        ...  ...                  ...                  ...
# 4120                     0.292  ...                0.174                0.176
# 4121                     0.326  ...                0.692                0.783
# 4122                     0.219  ...                1.424                0.695
# 4123                     0.235  ...                0.221                0.221
# 4124                     0.067  ...                0.172                 0.21
#
#                           8752                 8753                 8754  \
# timestamp  2013-12-31 16:00:00  2013-12-31 17:00:00  2013-12-31 18:00:00
# 0                        0.841                0.747                0.477
# 1                        0.174                0.192                0.113
# 2                          0.0                0.147                  0.0
# 3                        0.134                0.199                1.042
# ...                        ...                  ...                  ...
# 4120                     0.243                0.751                0.381
# 4121                     0.928                0.496                0.413
# 4122                     2.219                2.529                0.907
# 4123                     0.219                0.205                0.209
# 4124                     0.418                0.398                0.737
#
#                           8755                 8756                 8757  \
# timestamp  2013-12-31 19:00:00  2013-12-31 20:00:00  2013-12-31 21:00:00
# 0                        0.559                1.233                0.783
# 1                        0.221                 0.14                 0.12
# 2                        0.169                  0.0                0.178
# 3                        0.281                0.286                0.209
# ...                        ...                  ...                  ...
# 4120                     0.216                0.267                0.279
# 4121                     0.649                0.263                0.294
# 4122                     0.928                0.774                0.802
# 4123                      0.22                0.221                 0.22
# 4124                     0.227                0.112                0.104
#
#                           8758                 8759
# timestamp  2013-12-31 22:00:00  2013-12-31 23:00:00
# 0                        0.858                0.943
# 1                        0.484                0.149
# 2                          0.0                0.157
# 3                        0.467                0.282
# ...                        ...                  ...
# 4120                     0.217                0.218
# 4121                     0.282                0.187
# 4122                     0.874                  1.0
# 4123                      0.17                0.168
# 4124                     0.101                0.119
#
# [4126 rows x 8760 columns]

# %% [markdown]
# # Visualize the mean

# %%
dataset.iloc[1:,:].mean(axis = 0).plot()
# Out:
# <Axes: >

# %% [markdown]
# # Visualize a single data sample

# %%
dataset.iloc[1,:].plot()
# Out:
# <Axes: >
